# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekanand04/Probability-and-Stats/blob/feature%2Fupdate/Probability_Density_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/035/126/original/weight-height.csv?1684995383 -O weight-height.csv
# Out:
# --2024-10-07 17:35:57--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/035/126/original/weight-height.csv?1684995383
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 18.164.173.18, 18.164.173.110, 18.164.173.117, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|18.164.173.18|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 428120 (418K) [text/plain]
# Saving to: ‘weight-height.csv’
#
# weight-height.csv   100%[===================>] 418.09K  --.-KB/s    in 0.04s
#
# 2024-10-07 17:35:58 (10.7 MB/s) - ‘weight-height.csv’ saved [428120/428120]

# %%
df_hw = pd.read_csv('weight-height.csv')
df_hw
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
df_hw['Height'].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
df_hw['Height'].max()
# Out:
# 78.9987423463896

# %%
df_height = df_hw['Height']
df_height
# Out:
# 0       73.847017
# 1       68.781904
# 2       74.110105
# 3       71.730978
# 4       69.881796
#           ...
# 9995    66.172652
# 9996    67.067155
# 9997    63.867992
# 9998    69.034243
# 9999    61.944246
# Name: Height, Length: 10000, dtype: float64

# %%
#sample = 5000
df_height.sample(5000)
# Out:
# 7253    64.715292
# 1816    70.952009
# 1934    71.358211
# 3325    63.008723
# 1883    71.094273
#           ...
# 2706    72.629123
# 3237    68.419983
# 2770    69.380303
# 7797    68.101674
# 9602    64.083912
# Name: Height, Length: 5000, dtype: float64

# %%
df_hw['Height'].mean()
# Out:
# 66.36755975482124

# %%
df_hw['Height'].var()
# Out:
# 14.8034726401408

# %%
df_hw['Height'].std()
# Out:
# 3.8475281207732324

# %%
sns.histplot(df_height)
# Out:
# <Axes: xlabel='Height', ylabel='Count'>

# %%
df_hw['Height'].min()
# Out:
# 54.2631333250971

# %%
df_hw['Height'].max()
# Out:
# 78.9987423463896

# %%
x_values = np.linspace(df_height.min(),df_height.max(),10000)
y_values = []

# %%
x_values[:5]
# Out:
# array([54.26313333, 54.26560713, 54.26808094, 54.27055475, 54.27302856])

# %%
len(x_values)
# Out:
# 10000

# %%
x_values
# Out:
# array([54.26313333, 54.26560713, 54.26808094, ..., 78.99379473,
#        78.99626854, 78.99874235])

# %%
for x in x_values:
       people_shorter_than_x  =  len(df_height[df_height <= x])
       fraction = people_shorter_than_x/len(df_height)
       y_values.append(fraction)

# %%
len(y_values)
# Out:
# 10000

# %%
y_values
# Out:
# [0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
#  0.0001,
# ...

# %%
plt.plot(x_values,y_values)

# %%
x = np.linspace(2,3,5)
x
# Out:
# array([2.  , 2.25, 2.5 , 2.75, 3.  ])

# %%
np.linspace?

# %% [markdown]
# #empirical probability

# %%
np.random.choice(['H','T'],size=2)
# Out:
# array(['T', 'H'], dtype='<U1')

# %%
np.random.choice(['H','T'],size=2)
# Out:
# array(['H', 'H'], dtype='<U1')

# %%
np.random.choice(['H','T'],size=10)
# Out:
# array(['T', 'H', 'T', 'H', 'T', 'T', 'T', 'H', 'T', 'H'], dtype='<U1')

# %%
np.random.choice(['H','T'],size=1000000)
# Out:
# array(['H', 'H', 'T', ..., 'T', 'H', 'H'], dtype='<U1')

# %%
pd.value_counts(np.random.choice(['H','T'],size=1000000))
# Out:
# <ipython-input-37-71a43f7620dd>:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(np.random.choice(['H','T'],size=1000000))
# <ipython-input-37-71a43f7620dd>:1: FutureWarning: The behavior of value_counts with object-dtype is deprecated. In a future version, this will *not* perform dtype inference on the resulting index. To retain the old behavior, use `result.index = result.index.infer_objects()`
#   pd.value_counts(np.random.choice(['H','T'],size=1000000))
# T    500127
# H    499873
# Name: count, dtype: int64

# %%
pd.value_counts(np.random.choice(['H','T'],size=1000000),normalize= True)
# Out:
# <ipython-input-38-4ccc57147822>:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(np.random.choice(['H','T'],size=1000000),normalize= True)
# <ipython-input-38-4ccc57147822>:1: FutureWarning: The behavior of value_counts with object-dtype is deprecated. In a future version, this will *not* perform dtype inference on the resulting index. To retain the old behavior, use `result.index = result.index.infer_objects()`
#   pd.value_counts(np.random.choice(['H','T'],size=1000000),normalize= True)
# T    0.500029
# H    0.499971
# Name: proportion, dtype: float64

# %% [markdown]
# #casino case study

# %%
rolls = np.random.choice(['R','R','R','B','B'],size =4)

# %%
rolls
# Out:
# array(['R', 'R', 'R', 'B'], dtype='<U1')

# %%
pd.value_counts(rolls)
# Out:
# <ipython-input-10-da703b938af1>:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(rolls)
# <ipython-input-10-da703b938af1>:1: FutureWarning: The behavior of value_counts with object-dtype is deprecated. In a future version, this will *not* perform dtype inference on the resulting index. To retain the old behavior, use `result.index = result.index.infer_objects()`
#   pd.value_counts(rolls)
# R    3
# B    1
# Name: count, dtype: int64

# %%
rolls
# Out:
# array(['R', 'R', 'R', 'B'], dtype='<U1')

# %%
len(rolls[rolls == 'R'])
# Out:
# 3

# %%
#probablities using empirical
red_values = []
for x in range(10000):
  rolls = np.random.choice(['R','R','R','B','B'],size =4)
  num_red  = len(rolls[rolls == 'R'])
  red_values.append(num_red)

# %%
red_values
# Out:
# [2,
#  3,
#  2,
#  2,
#  3,
#  3,
#  2,
#  2,
#  2,
#  3,
#  3,
#  4,
#  3,
#  2,
#  3,
#  1,
#  1,
#  3,
#  1,
#  3,
#  4,
#  2,
#  1,
#  4,
#  2,
#  2,
#  1,
#  2,
#  1,
#  4,
#  2,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  3,
#  3,
#  2,
#  1,
#  2,
#  2,
#  0,
#  3,
#  3,
#  4,
#  4,
#  2,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  3,
#  4,
#  4,
#  4,
#  1,
#  3,
#  3,
#  1,
#  1,
#  3,
#  2,
#  3,
#  1,
#  2,
#  3,
#  3,
#  4,
#  3,
#  3,
#  1,
#  3,
#  2,
#  3,
#  2,
#  2,
#  2,
#  2,
#  2,
#  3,
#  4,
#  4,
#  2,
#  2,
#  2,
#  2,
#  1,
#  0,
#  4,
#  2,
#  3,
#  2,
#  4,
#  3,
#  2,
#  2,
#  3,
#  2,
#  2,
#  4,
#  3,
#  3,
#  2,
#  1,
#  2,
#  3,
#  2,
#  2,
#  4,
#  2,
#  4,
#  3,
#  3,
#  1,
#  1,
#  3,
#  3,
#  1,
#  2,
#  3,
#  3,
#  4,
#  1,
#  4,
#  3,
#  4,
#  3,
#  0,
#  2,
#  2,
#  3,
#  2,
#  4,
#  1,
#  2,
#  2,
#  2,
#  2,
#  4,
#  2,
#  3,
#  3,
#  3,
#  1,
#  3,
#  2,
#  2,
#  1,
#  4,
#  2,
#  3,
#  3,
#  2,
#  2,
# ...

# %%
x = pd.value_counts(red_values,normalize=True)
x
# Out:
# <ipython-input-19-20c571f32fb4>:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   x = pd.value_counts(red_values,normalize=True)
# <ipython-input-19-20c571f32fb4>:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   x = pd.value_counts(red_values,normalize=True)
# 2    0.3457
# 3    0.3457
# 1    0.1541
# 4    0.1290
# 0    0.0255
# Name: proportion, dtype: float64

# %%
pd.value_counts(red_values)
# Out:
# <ipython-input-16-930602aa7faf>:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(red_values)
# <ipython-input-16-930602aa7faf>:1: FutureWarning: value_counts with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pd.value_counts(red_values)
# 2    3457
# 3    3457
# 1    1541
# 4    1290
# 0     255
# Name: count, dtype: int64

# %%
#avg number of getting the red balls or expected probability E[X]
(3*3453 + 2*3436 + 1*1562 + 4*1282 + 0*267)/10000
# Out:
# 2.3921

# %%
x
# Out:
# 2    0.3457
# 3    0.3457
# 1    0.1541
# 4    0.1290
# 0    0.0255
# Name: proportion, dtype: float64

# %%
sns.barplot(x=x.index, y=x.values)
plt.show() #PMF

# %%
#binomail formula
from scipy.stats  import binom

# %%
binom.pmf(n=4,p=3/5,k=0)
# Out:
# 0.025599999999999994

# %%
binom.pmf(n=4,p=3/5,k=1) #p => success => red ball => 3/5
# Out:
# 0.15359999999999996

# %%
binom.pmf(n=4,p=3/5,k=2)
# Out:
# 0.3456

# %%
binom.pmf(n=4,p=3/5,k=3)
# Out:
# 0.3456000000000001

# %%
binom.pmf(n=4,p=3/5,k=4)
# Out:
# 0.1296

# %%
binom.pmf(n=1,p=3/5,k=0)
# Out:
# 0.4000000000000001

# %%
binom.pmf(n=1,p=3/5,k=1)
# Out:
# 0.6

# %%
1 - (binom.pmf(n=10,p=1/4,k=0) + binom.pmf(n=10,p=1/4,k=1) +binom.pmf(n=10,p=1/4,k=2)+binom.pmf(n=10,p=1/4,k=3) )
# Out:
# 0.22412490844726585

# %%
# 1 - binom.pmf(n=10,p=1/4,k<=3)

# %%
1 - binom.cdf(n=10,p=1/4,k=3)
# Out:
# 0.22412490844726562
