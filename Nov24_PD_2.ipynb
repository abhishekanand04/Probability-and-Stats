# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekanand04/Probability-and-Stats/blob/feature%2Fupdate/Nov24_PD_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate random data following a uniform distribution
data = np.random.uniform(1, 7, 10000)  # 10,000 samples from a uniform distribution between 1 and 6

# Create a histogram
plt.hist(data, bins=6, edgecolor='black', align='mid', rwidth=0.8, density=True, color='skyblue')

# Set labels and title
plt.xlabel('Outcome')
plt.ylabel('Probability')
plt.title('Histogram of a Uniform Distribution (Die Roll Simulation)')

# Show the plot
plt.grid(True)
plt.show()

# %%
# Generate random data following a uniform distribution
data = np.random.uniform(1, 7, 100)  # 100 samples from a uniform distribution between 1 and 6

# Create a histogram
plt.hist(data, bins=6, edgecolor='black', align='mid', rwidth=0.8, density=True, color='skyblue')

# Set labels and title
plt.xlabel('Outcome')
plt.ylabel('Probability')
plt.title('Histogram of a Uniform Distribution (Die Roll Simulation)')

# Show the plot
plt.grid(True)
plt.show()
