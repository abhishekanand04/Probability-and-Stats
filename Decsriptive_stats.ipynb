# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekanand04/Probability-and-Stats/blob/feature%2Fupdate/Decsriptive_stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
(24*4) - (20+22+28)
# Out:
# 26

# %%
# !wget --no-check-certificate https://drive.google.com/uc?id=1JYyGv7QSb_GkVGan5rnHNrtOg2ewJB_f -O sehwag.csv
# Out:
# --2024-09-30 17:15:54--  https://drive.google.com/uc?id=1JYyGv7QSb_GkVGan5rnHNrtOg2ewJB_f
# Resolving drive.google.com (drive.google.com)... 173.194.216.102, 173.194.216.100, 173.194.216.139, ...
# Connecting to drive.google.com (drive.google.com)|173.194.216.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1JYyGv7QSb_GkVGan5rnHNrtOg2ewJB_f [following]
# --2024-09-30 17:15:54--  https://drive.usercontent.google.com/download?id=1JYyGv7QSb_GkVGan5rnHNrtOg2ewJB_f
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.141.132, 2607:f8b0:400c:c06::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.141.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
sehwag = pd.read_csv("sehwag.csv")
sehwag.head()
# Out:
#    Runs Mins  BF  4s  6s      SR  Pos Dismissal  Inns  Unnamed: 9  \
# 0     1    5   2   0   0   50.00    7       lbw     1         NaN
# 1    19   18  24   0   1   79.16    6    caught     1         NaN
# 2    58   62  54   8   0  107.40    6    bowled     1         NaN
# 3     2    7   7   0   0   28.57    6    caught     2         NaN
# 4    11   19  16   1   0   68.75    6   not out     2         NaN
#
#       Opposition     Ground   Start Date Unnamed: 13
# 0     v Pakistan     Mohali   1 Apr 1999  ODI # 1427
# 1     v Zimbabwe     Rajkot  14 Dec 2000  ODI # 1660
# 2    v Australia  Bengaluru  25 Mar 2001  ODI # 1696
# 3     v Zimbabwe   Bulawayo  27 Jun 2001  ODI # 1730
# 4  v West Indies   Bulawayo  30 Jun 2001  ODI # 1731

# %%
sehwag['Runs'].describe()
# Out:
# count    245.000000
# mean      33.767347
# std       34.809419
# min        0.000000
# 25%        8.000000
# 50%       23.000000
# 75%       46.000000
# max      219.000000
# Name: Runs, dtype: float64

# %%
#25th percentile or Q1
p_25 = np.percentile(sehwag['Runs'],25)
p_25
# Out:
# 8.0

# %%
#50th percentile or Q2 or median
p_50 = np.percentile(sehwag['Runs'],50)
p_50
# Out:
# 23.0

# %%
#75th percentile or Q3
p_75 = np.percentile(sehwag['Runs'],75)
p_75
# Out:
# 46.0

# %%
#IQR => Q3-Q1
iqr_sehwag = p_75 - p_25

# %%
iqr_sehwag
# Out:
# 38.0

# %%
#normal range
normal_range = sehwag['Runs'].max() - sehwag['Runs'].min()
normal_range
# Out:
# 219

# %%
sns.boxplot(data=sehwag['Runs'])
plt.show()

# %%
#upper limit = q3 + 1.5*iqr
upper = 46 +  1.5 * 38
upper
# Out:
# 103.0

# %%
len(sehwag[sehwag['Runs']>upper])
# Out:
# 14

# %%
sehwag[sehwag['Runs']>upper]
# Out:
#      Runs Mins   BF  4s  6s      SR  Pos Dismissal  Inns  Unnamed: 9  \
# 37    126  136  104  21   1  121.15    1    caught     2         NaN
# 43    114    -   82  17   2  139.02    2   not out     2         NaN
# 49    108  160  119   9   2   90.75    2   run out     2         NaN
# 53    112  175  139  11   3   80.57    2    caught     2         NaN
# 75    130  193  134  15   2   97.01    1    caught     1         NaN
# 104   108  156   95   9   3  113.68    1    bowled     1         NaN
# 163   114  127   87  17   3  131.03    3    caught     1         NaN
# 182   119  150   95  12   5  125.26    2    caught     2         NaN
# 192   116  165   90  17   0  128.88    1   run out     1         NaN
# 198   125  106   74  14   6  168.91    2   not out     2         NaN
# 206   146  166  102  17   6  143.13    1    caught     1         NaN
# 220   110  136   93  16   1  118.27    2    caught     1         NaN
# 222   175  198  140  14   5  125.00    1    bowled     1         NaN
# ...

# %%
14/245 * 100
# Out:
# 5.714285714285714

# %% [markdown]
# #Dravid  data

# %%
dravid = pd.read_csv("dravid.csv")
dravid.head()
# Out:
#    Runs Mins  BF  4s  6s      SR  Pos Dismissal  Inns  Unnamed: 9  \
# 0     3    -   4   0   0   75.00    4    caught     1         NaN
# 1     4    -   7   0   0   57.14    4   run out     1         NaN
# 2     3    -   5   0   0   60.00    5    caught     2         NaN
# 3    11   28  21   0   0   52.38    8    caught     2         NaN
# 4    22   21  15   3   0  146.66    6   not out     1         NaN
#
#        Opposition      Ground   Start Date Unnamed: 13
# 0     v Sri Lanka   Singapore   3 Apr 1996  ODI # 1089
# 1      v Pakistan   Singapore   5 Apr 1996  ODI # 1091
# 2      v Pakistan     Sharjah  12 Apr 1996  ODI # 1094
# 3  v South Africa     Sharjah  14 Apr 1996  ODI # 1097
# 4       v England  Manchester  26 May 1996  ODI # 1104

# %%
dravid["Runs"].describe()
# Out:
# count    318.000000
# mean      34.242138
# std       29.681822
# min        0.000000
# 25%       10.000000
# 50%       26.000000
# 75%       54.000000
# max      153.000000
# Name: Runs, dtype: float64

# %%
#25th percentile or Q1
per_25 = np.percentile(dravid["Runs"], 25)
per_25
# Out:
# 10.0

# %%
#50th percentile or Q2 , also "Median"
per_50 = np.percentile(dravid["Runs"], 50)
per_50
# Out:
# 26.0

# %%
#75th percentile or Q3
per_75 = np.percentile(dravid["Runs"], 75)
per_75
# Out:
# 54.0

# %%
# Inter Quartile Range
iqr_dravid = per_75 - per_25
iqr_dravid
# Out:
# 44.0

# %%
normal_range = (dravid["Runs"].max() - dravid["Runs"].min())

normal_range
# Out:
# 153

# %%
 sns.boxplot(data=dravid["Runs"])
 plt.show()

# %%
upper_dravid = per_75 + 1.5*(iqr_dravid)
upper_dravid
# Out:
# 120.0

# %%
# all the values greater than upper is outlier
outliers_dravid = dravid[dravid["Runs"]>upper_dravid]
outliers_dravid
# Out:
#     Runs Mins   BF  4s  6s     SR  Pos Dismissal  Inns  Unnamed: 9  \
# 58   123  201  123  10   1  100.0    3   not out     1         NaN
# 76   145  179  129  17   1  112.4    3   run out     1         NaN
# 97   153  196  153  15   2  100.0    3    caught     1         NaN
#
#        Opposition              Ground   Start Date Unnamed: 13
# 58  v New Zealand               Taupo   9 Jan 1999  ODI # 1378
# 76    v Sri Lanka             Taunton  26 May 1999  ODI # 1463
# 97  v New Zealand  Hyderabad (Deccan)   8 Nov 1999  ODI # 1523

# %%
len(outliers_dravid)
# Out:
# 3

# %%
len(outliers_dravid)/len(dravid) * 100
# Out:
# 0.9433962264150944
